# %%
# !git --version
# Out:
# git version 2.39.5 (Apple Git-154)

# %%
cd MyMLwork
git init
git add .
git commit -m "Added all projects"
git remote add origin https://github.com/killersparsh123/MyMLwork.git
git push -u origin main
# Out:
#   Cell In[2], line 1
#     cd MyMLwork
#        ^
# SyntaxError: invalid syntax

# %%
import os
print(os.getcwd())
# Out:
# /Users/stutipangeni/100_days_of_ml
