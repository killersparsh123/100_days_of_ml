# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv("placement.csv")
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
plt.scatter(df['cgpa'],df['package'])

# %%
x=df.iloc[:,0:1]
y=df.iloc[:,-1]
x
# Out:
#      cgpa
# 0    6.89
# 1    5.12
# 2    7.82
# 3    7.42
# 4    6.94
# ..    ...
# 195  6.93
# 196  5.89
# 197  7.21
# 198  7.63
# 199  6.22
#
# [200 rows x 1 columns]

# %%
y
# Out:
# 0      3.26
# 1      1.98
# 2      3.25
# 3      3.67
# 4      3.57
#        ...
# 195    2.46
# 196    2.57
# 197    3.24
# 198    3.96
# 199    2.33
# Name: package, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 from sklearn.model_selection import train_test_split
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
# !pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.9.0-cp313-cp313-macosx_12_0_arm64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.24.1 in /opt/anaconda3/envs/sparshML/lib/python3.13/site-packages (from scikit-learn) (2.4.6)
# Collecting scipy>=1.10.0 (from scikit-learn)
#   Downloading scipy-1.17.1-cp313-cp313-macosx_14_0_arm64.whl.metadata (62 kB)
# Collecting joblib>=1.4.0 (from scikit-learn)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting narwhals>=2.0.1 (from scikit-learn)
#   Downloading narwhals-2.22.1-py3-none-any.whl.metadata (15 kB)
# Collecting threadpoolctl>=3.5.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.9.0-cp313-cp313-macosx_12_0_arm64.whl (8.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 575.1 kB/s  0:00:14 eta 0:00:01
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading narwhals-2.22.1-py3-none-any.whl (454 kB)
# Downloading scipy-1.17.1-cp313-cp313-macosx_14_0_arm64.whl (20.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.3/20.3 MB 182.9 kB/s  0:00:58m0:00:0100:04
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, narwhals, joblib, scikit-learn
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [scikit-learn] [scikit-learn]
# Successfully installed joblib-1.5.3 narwhals-2.22.1 scikit-learn-1.9.0 scipy-1.17.1 threadpoolctl-3.6.0

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1)
x_train
# Out:
#      cgpa
# 187  6.26
# 81   6.10
# 56   5.84
# 70   5.79
# 139  7.19
# ..    ...
# 13   6.93
# 192  8.25
# 161  7.30
# 178  8.15
# 152  7.37
#
# [180 rows x 1 columns]

# %%
x_train
# Out:
#      cgpa
# 81   6.10
# 74   6.85
# 174  7.32
# 24   6.53
# 141  6.76
# ..    ...
# 153  7.94
# 20   7.28
# 171  8.01
# 88   4.73
# 176  6.29
#
# [180 rows x 1 columns]

# %%
y_train
# Out:
# 187    2.44
# 81     2.20
# 56     2.74
# 70     2.35
# 139    2.40
#        ...
# 13     2.89
# 192    3.75
# 161    3.33
# 178    3.63
# 152    3.08
# Name: package, Length: 180, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_train
# Out:
# array([[-0.70691847],
#        [-0.85585228],
#        [-1.09786973],
#        [-1.14441154],
#        [ 0.15875931],
#        [-0.66037666],
#        [ 0.11221749],
#        [ 0.92204509],
#        [-0.88377737],
#        [-0.15772504],
#        [ 0.70795273],
#        [-0.28804213],
#        [-0.05533305],
#        [ 0.54971056],
#        [ 1.47123852],
#        [ 0.38216002],
#        [-2.13109804],
#        [-0.25080867],
#        [-1.38642898],
#        [ 1.01512872],
#        [ 0.85688655],
#        [-0.51144284],
#        [ 2.1321323 ],
#        [-1.26542026],
#        [ 0.25184294],
#        [-0.12049159],
#        [-0.89308574],
#        [-0.47420939],
#        [ 0.29838475],
#        [ 0.80103637],
#        [-0.24150031],
#        [-0.79069374],
#        [-0.85585228],
#        [-0.74415192],
#        [-0.66968502],
#        [ 0.24253457],
#        [ 0.66141092],
#        [-1.10717809],
#        [-1.77738024],
#        [-0.14841668],
#        [ 0.17737603],
#        [ 1.83426468],
#        [-0.03671632],
#        [-0.96755264],
#        [-0.08325814],
#        [-1.09786973],
#        [ 0.56832729],
#        [-2.56859111],
#        [-0.39974249],
#        [ 0.68933601],
#        [ 0.14945094],
#        [-0.07394977],
#        [ 0.82896146],
#        [ 0.81965309],
#        [ 0.81034473],
#        [ 0.24253457],
#        [ 0.50316874],
#        [ 0.76380291],
#        [-0.63245157],
#        [-0.22288359],
#        [-0.38112576],
#        [ 2.19729084],
#        [ 0.30769312],
#        [ 2.38345811],
#        [-1.09786973],
#        [-0.36250903],
#        [-1.04201955],
#        [ 0.82896146],
#        [ 1.45262179],
#        [-0.82792719],
#        [ 0.69864437],
#        [-0.60452648],
#        [-2.07524786],
#        [-0.12049159],
#        [ 0.37285166],
#        [-0.38112576],
#        [ 0.42870184],
#        [-1.33988717],
#        [-2.28003185],
#        [ 1.25714616],
#        [ 0.16806767],
#        [-0.33458394],
#        [ 0.35423493],
#        [-1.31196208],
#        [ 0.81034473],
#        [-1.75876351],
#        [ 0.31700148],
#        [-1.03271118],
#        [-0.48351775],
#        [-0.9023941 ],
#        [-2.01939768],
#        [ 0.86619491],
#        [ 1.11752071],
#        [-0.31596722],
#        [-1.58190461],
#        [ 1.00582036],
#        [ 0.2611513 ],
#        [-0.0925665 ],
#        [-1.76807188],
#        [ 1.57363051],
#        [-0.07394977],
#        [-0.16703341],
#        [ 0.02844222],
#        [ 1.99250685],
#        [-0.74415192],
#        [ 2.08559049],
#        [ 0.11221749],
#        [ 0.50316874],
#        [-0.86516065],
#        [-1.09786973],
#        [ 0.33561821],
#        [-0.77207701],
#        [ 0.62417747],
#        [ 1.08028726],
#        [-0.67899338],
#        [-1.48882098],
#        [-1.7866886 ],
#        [ 1.51778033],
#        [ 0.55901892],
#        [-0.08325814],
#        [-0.07394977],
#        [-1.00478609],
#        [-0.6231432 ],
#        [-1.4329708 ],
#        [ 1.48985524],
#        [-0.74415192],
#        [-0.99547773],
#        [-0.39043412],
#        [-0.08325814],
#        [ 0.59625238],
#        [-0.45559267],
#        [ 0.06567567],
#        [-0.21357522],
#        [ 0.24253457],
#        [ 0.0842924 ],
#        [ 1.03374545],
#        [ 0.41939347],
#        [-0.25080867],
#        [ 1.20129598],
#        [ 0.34492657],
#        [-0.2694254 ],
#        [-0.83723556],
#        [ 0.24253457],
#        [ 0.99651199],
#        [ 1.72256432],
#        [-1.28403699],
#        [ 1.20129598],
#        [-0.88377737],
#        [-0.04602468],
#        [ 1.09890399],
#        [-1.09786973],
#        [ 1.89942322],
#        [ 0.31700148],
#        [-0.99547773],
#        [ 0.21460948],
#        [ 0.791728  ],
#        [ 0.12152585],
#        [ 1.8808065 ],
#        [ 1.10821235],
#        [ 1.17337089],
#        [ 0.09360076],
#        [-0.55798466],
#        [-0.07394977],
#        [ 0.84757818],
#        [ 1.7784145 ],
#        [-1.52605443],
#        [ 1.78772286],
#        [ 1.3223047 ],
#        [ 1.3223047 ],
#        [ 0.0842924 ],
#        [-0.81861883],
#        [-1.79599696],
#        [-0.77207701],
#        [ 0.27976803],
#        [ 0.74518619],
#        [-0.08325814],
#        [ 1.1454458 ],
#        [ 0.2611513 ],
#        [ 1.05236217],
#        [ 0.32630984]])

# %%
x_test=scaler.transform(x_test)
x_test
# Out:
# array([[-1.66567988],
#        [-0.51144284],
#        [ 0.51247711],
#        [ 1.49916361],
#        [ 0.01913386],
#        [-1.05132791],
#        [ 0.10290913],
#        [-0.95824428],
#        [-1.76807188],
#        [ 0.56832729],
#        [-1.06063627],
#        [-0.64175993],
#        [-0.15772504],
#        [ 0.05636731],
#        [ 1.23852944],
#        [-0.13910832],
#        [ 0.28907639],
#        [-0.77207701],
#        [-1.48882098],
#        [ 0.5404022 ]])

# %%
from sklearn.linear_model import LogisticRegression
clf=LogisticRegression()
clf.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 3
#       1 from sklearn.linear_model import LogisticRegression
#       2 clf=LogisticRegression()
# ----> 3 clf.fit(x_train,y_train)
#
# File /opt/anaconda3/envs/sparshML/lib/python3.13/site-packages/sklearn/base.py:1403, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1393     estimator._validate_params()
#    1395 with (
#    1396     config_context(
#    1397         skip_parameter_validation=(
#    (...)   1401     callback_management_context(estimator),
#    1402 ):
# -> 1403     return fit_method(estimator, *args, **kwargs)
#
# File /opt/anaconda3/envs/sparshML/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:1469, in LogisticRegression.fit(self, X, y, sample_weight)
#    1459 X, y = validate_data(
#    1460     self,
#    1461     X,
#    (...)   1466     accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1467 )
#    1468 n_features = X.shape[1]
# -> 1469 check_classification_targets(y)
#    1470 self.classes_ = xp_y.unique_values(y)
#    1471 n_classes = size(self.classes_)
#
# File /opt/anaconda3/envs/sparshML/lib/python3.13/site-packages/sklearn/utils/multiclass.py:230, in check_classification_targets(y)
#     222 y_type = type_of_target(y, input_name="y")
#     223 if y_type not in [
#     224     "binary",
#     225     "multiclass",
#    (...)    228     "multilabel-sequences",
#     229 ]:
# --> 230     raise ValueError(
#     231         f"Unknown label type: {y_type}. Maybe you are trying to fit a "
#     232         "classifier, which expects discrete classes on a "
#     233         "regression target with continuous values."
#     234     )
#     236 if "multiclass" in y_type:
#     237     n_samples = _num_samples(y)
#
# ValueError: Unknown label type: continuous. Maybe you are trying to fit a classifier, which expects discrete classes on a regression target with continuous values.

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()
