# %%
import pandas as pd
df=pd.read_csv("placement-dataset.csv")

# %% [markdown]
# 1) HOW BIG IS THE DATA

# %%
df.shape
# Out:
# (100, 4)

# %% [markdown]
# 2) HOW DOES THE DATA LOOK LIKE?

# %%
df.head()
# Out:
#           city  cgpa     iq  placement
# 0     New York   6.8  123.0          1
# 1  Los Angeles   5.9  106.0          0
# 2      Chicago   NaN  121.0          0
# 3     New York   7.4  132.0          1
# 4  Los Angeles   5.8  142.0          0

# %% [markdown]
# for random data

# %%
df.sample(5)
# Out:
#            city  cgpa     iq  placement
# 14      Chicago   NaN  103.0          0
# 6      New York   5.7    NaN          0
# 9      New York   5.1   66.0          0
# 49  Los Angeles   5.4  135.0          0
# 23      Chicago   NaN   87.0          0

# %% [markdown]
# 3) WHAT IS THE DATA TYPE OF COLS?

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   city       100 non-null    str
#  1   cgpa       92 non-null     float64
#  2   iq         96 non-null     float64
#  3   placement  100 non-null    int64
# dtypes: float64(2), int64(1), str(1)
# memory usage: 3.3 KB

# %% [markdown]
# 4) ARE THERE ANY MISSING VALUES?

# %%
df.isnull().sum()
# Out:
# city         0
# cgpa         8
# iq           4
# placement    0
# dtype: int64

# %% [markdown]
# 5) how does the data look mathematically?

# %%
df.describe()
# Out:
#             cgpa          iq   placement
# count  92.000000   96.000000  100.000000
# mean    5.965217  117.916667    0.460000
# std     1.164911   46.913508    0.500908
# min     3.300000    1.000000    0.000000
# 25%     5.000000   90.000000    0.000000
# 50%     6.000000  122.000000    0.000000
# 75%     6.825000  146.750000    1.000000
# max     8.500000  233.000000    1.000000

# %% [markdown]
# 6) are there duplicate values?

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %% [markdown]
# 7)HOW IS THE CORRELATION BETWEEEN COLS?

# %%
df.corr()['cgpa']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df.corr()['cgpa']
#
# File /opt/anaconda3/envs/sparshML/lib/python3.13/site-packages/pandas/core/frame.py:13133, in DataFrame.corr(self, method, min_periods, numeric_only)
#   13129         """  # noqa: E501
#   13130         data = self._get_numeric_data() if numeric_only else self
#   13131         cols = data.columns
#   13132         idx = cols.copy()
# > 13133         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   13134
#   13135         if method == "pearson":
#   13136             correl = libalgos.nancorr(mat, minp=min_periods)
#
# File /opt/anaconda3/envs/sparshML/lib/python3.13/site-packages/pandas/core/frame.py:2081, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    2077                [2, 4.5, Timestamp('2000-01-02 00:00:00')]], dtype=object)
#    2078         """
#    2079         if dtype is not None:
#    2080             dtype = np.dtype(dtype)
# -> 2081         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    2082         if result.dtype is not dtype:
#    2083             result = np.asarray(result, dtype=dtype)
#    2084
#
# File /opt/anaconda3/envs/sparshML/lib/python3.13/site-packages/pandas/core/internals/managers.py:1872, in BlockManager.as_array(self, dtype, copy, na_value)
#    1870         arr.flags.writeable = False
#    1871 else:
# -> 1872     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1873     # The underlying data was copied within _interleave, so no need
#    1874     # to further copy if copy=True or setting na_value
#    1876 if na_value is lib.no_default:
#
# File /opt/anaconda3/envs/sparshML/lib/python3.13/site-packages/pandas/core/internals/managers.py:1925, in BlockManager._interleave(self, dtype, na_value)
#    1919 rl = blk.mgr_locs
#    1920 if blk.is_extension:
#    1921     # Avoid implicit conversion of extension blocks to object
#    1922
#    1923     # error: Item "ndarray" of "Union[ndarray, ExtensionArray]" has no
#    1924     # attribute "to_numpy"
# -> 1925     arr = blk.values.to_numpy(  # type: ignore[union-attr]
#    1926         dtype=dtype,
#    1927         na_value=na_value,
#    1928     )
#    1929 else:
#    1930     arr = blk.get_values(dtype)
#
# File /opt/anaconda3/envs/sparshML/lib/python3.13/site-packages/pandas/core/arrays/numpy_.py:589, in NumpyExtensionArray.to_numpy(self, dtype, copy, na_value)
#     586         result = result.view()
#     587         result.flags.writeable = False
# --> 589 result = np.asarray(result, dtype=dtype)
#     591 if copy and result is self._ndarray:
#     592     result = result.copy()
#
# ValueError: could not convert string to float: 'New York'
