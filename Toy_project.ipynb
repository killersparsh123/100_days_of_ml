# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("placement-dataset.csv")
df.head()
# Out:
#           city  cgpa     iq  placement
# 0     New York   6.8  123.0          1
# 1  Los Angeles   5.9  106.0          0
# 2      Chicago   NaN  121.0          0
# 3     New York   7.4  132.0          1
# 4  Los Angeles   5.8  142.0          0

# %%
plt.scatter(df['cgpa'],df['placement'])
plt.show()

# %%
df.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df.show()
#
# File /opt/anaconda3/envs/sparshML/lib/python3.13/site-packages/pandas/core/generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'show'

# %%
pd.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 pd.show()
#
# AttributeError: module 'pandas' has no attribute 'show'

# %%
df.describe()
# Out:
#             cgpa          iq   placement
# count  92.000000   96.000000  100.000000
# mean    5.965217  117.916667    0.460000
# std     1.164911   46.913508    0.500908
# min     3.300000    1.000000    0.000000
# 25%     5.000000   90.000000    0.000000
# 50%     6.000000  122.000000    0.000000
# 75%     6.825000  146.750000    1.000000
# max     8.500000  233.000000    1.000000

# %%
df.status()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df.status()
#
# File /opt/anaconda3/envs/sparshML/lib/python3.13/site-packages/pandas/core/generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'status'

# %%
df.status
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df.status
#
# File /opt/anaconda3/envs/sparshML/lib/python3.13/site-packages/pandas/core/generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'status'

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   city       100 non-null    str
#  1   cgpa       92 non-null     float64
#  2   iq         96 non-null     float64
#  3   placement  100 non-null    int64
# dtypes: float64(2), int64(1), str(1)
# memory usage: 3.3 KB

# %%
df['cgpa']=df['cgpa'].fillna(df['cgpa'].mean())

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   city       100 non-null    str
#  1   cgpa       100 non-null    float64
#  2   iq         96 non-null     float64
#  3   placement  100 non-null    int64
# dtypes: float64(2), int64(1), str(1)
# memory usage: 3.3 KB

# %%
df['iq']=df['iq'].fillna(df['iq'].mean())

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   city       100 non-null    str
#  1   cgpa       100 non-null    float64
#  2   iq         100 non-null    float64
#  3   placement  100 non-null    int64
# dtypes: float64(2), int64(1), str(1)
# memory usage: 3.3 KB

# %%
df.isnull().sum()
# Out:
# city         0
# cgpa         0
# iq           0
# placement    0
# dtype: int64

# %%
x=df.iloc[:,1:3]
y=df.iloc[:,-1]

# %%
x
# Out:
#         cgpa     iq
# 0   6.800000  123.0
# 1   5.900000  106.0
# 2   5.965217  121.0
# 3   7.400000  132.0
# 4   5.800000  142.0
# ..       ...    ...
# 95  4.300000  200.0
# 96  4.400000   42.0
# 97  6.700000  182.0
# 98  6.300000  103.0
# 99  6.200000  113.0
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1)

# %%
x_train
# Out:
#         cgpa     iq
# 62  6.000000  102.0
# 51  4.800000  141.0
# 93  6.800000  112.0
# 5   7.100000   48.0
# 29  5.965217    1.0
# ..       ...    ...
# 9   5.100000   66.0
# 33  6.000000  149.0
# 41  5.400000  114.0
# 61  7.300000  137.0
# 83  7.500000  130.0
#
# [90 rows x 2 columns]

# %%
y_test
# Out:
# 53    1
# 47    0
# 40    0
# 11    1
# 10    1
# 39    0
# 22    0
# 50    0
# 92    0
# 24    0
# Name: placement, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_train
# Out:
# array([[-0.02401537, -0.30348353],
#        [-1.14113505,  0.55858326],
#        [ 0.72073108, -0.08244076],
#        [ 1.00001099, -1.49711446],
#        [-0.05639566, -2.53601546],
#        [ 0.90691769,  1.8406313 ],
#        [-0.30329529,  0.53647898],
#        [ 0.06907793,  0.8901474 ],
#        [ 0.44145116,  0.31543621],
#        [-0.21020199,  0.58068753],
#        [-0.05639566,  0.11649772],
#        [ 0.53454446,  0.49227043],
#        [ 1.83785075, -0.81188189],
#        [ 1.18619761, -0.65715196],
#        [ 0.25526454,  0.27122766],
#        [ 1.93094406,  0.73541747],
#        [-0.30329529,  1.177503  ],
#        [ 0.90691769,  0.5143747 ],
#        [ 0.06907793, -0.76767334],
#        [ 0.06907793, -1.12134176],
#        [-0.30329529,  0.35964477],
#        [ 0.53454446,  0.09439345],
#        [-0.76876182,  2.39323821],
#        [-0.02401537, -1.09923749],
#        [ 0.72073108,  0.16070628],
#        [-1.8858815 , -0.900299  ],
#        [ 1.46547753, -0.59083913],
# ...

# %%
x_test=scaler.fit_transform(x_test)
x_test
# Out:
# array([[ 2.25330316,  0.67014346],
#        [-0.17212732,  0.51583411],
#        [-0.4068464 , -0.07935909],
#        [ 1.15794746,  0.00881768],
#        [ 0.45379022, -2.04129224],
#        [-0.64156548,  0.18517122],
#        [-0.4068464 , -0.38797779],
#        [-1.50220211,  2.10301598],
#        [-0.17212732, -0.60841972],
#        [-0.56332579, -0.3659336 ]])

# %%
from sklearn.linear_model import LogisticRegression
clf=LogisticRegression()
clf.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=clf.predict(x_test)

# %%
x_test
# Out:
# array([[ 2.25330316,  0.67014346],
#        [-0.17212732,  0.51583411],
#        [-0.4068464 , -0.07935909],
#        [ 1.15794746,  0.00881768],
#        [ 0.45379022, -2.04129224],
#        [-0.64156548,  0.18517122],
#        [-0.4068464 , -0.38797779],
#        [-1.50220211,  2.10301598],
#        [-0.17212732, -0.60841972],
#        [-0.56332579, -0.3659336 ]])

# %%
y_test
# Out:
# 53    1
# 47    0
# 40    0
# 11    1
# 10    1
# 39    0
# 22    0
# 50    0
# 92    0
# 24    0
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %% [markdown]
# FOR TEST AND TRAIN THE MODEL
# USE from sklearn.model_selection import train_test_split
# FOR SCALING AND PUTTING INTO MEAN=0 AND STD=1 FORM USE
# from sklearn.preprocessing import StandardScaler
# Scaler=StandardScaler()
# FOR LINEAR MODEL
# from sklearn.linear_model() import LogisticRegression/LinearRegression any model you would like to go with
# FOR PREDICTION USE
# as earlier we store all the regression into any form like clf=LogisticRegression and after that clf.fit(x_train,y_train)
# now for predicting clf.predict(x_test)
# and check printing output_test (y_test)
# for checking the prediction accuracy use
# from sklearn.metrics import accuracy_score
# accuracy_score(output,predicted)

# %%
from mlxtend.plotting import plot_decision_regions
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 from mlxtend.plotting import plot_decision_regions
#
# ModuleNotFoundError: No module named 'mlxtend'

# %%
import pickle
pickle.dump(clf,open("model.pkl:,"wb"))
# Out:
#   Cell In[43], line 2
#     pickle.dump(clf,open("model.pkl:,"wb"))
#                                         ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
import pickle

pickle.dump(clf, open("model.pkl", "wb"))

# %%
import pickle

model = pickle.load(open("model.pkl", "rb"))

# %%
model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 model.predict(X_test)
#
# NameError: name 'X_test' is not defined

# %%
import os

print(os.listdir())
# Out:
# ['Untitled1.ipynb', 'Untitled.ipynb', 'Toy_project.ipynb', 'model.pkl', 'placement.csv', '.ipynb_checkpoints', 'placement-dataset.csv']

# %%
import pickle

loaded_model = pickle.load(open("model.pkl", "rb"))

print(type(loaded_model))
# Out:
# <class 'sklearn.linear_model._logistic.LogisticRegression'>
